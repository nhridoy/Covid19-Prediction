# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import dask.dataframe as dd

# %%
url = "https://covid.ourworldindata.org/data/owid-covid-data.csv"

# %%
df = dd.read_csv(url, blocksize=None, dtype={'tests_units': 'object'})

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
worlddf = df[df["location"] == "World"]
countrydf = df[df["location"] == "Bangladesh"]

# %%
worlddf.head()
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 82045  OWID_WRL       NaN    World  2020-01-22        557.0        0.0
# 82046  OWID_WRL       NaN    World  2020-01-23        655.0       98.0
# 82047  OWID_WRL       NaN    World  2020-01-24        941.0      286.0
# 82048  OWID_WRL       NaN    World  2020-01-25       1433.0      492.0
# 82049  OWID_WRL       NaN    World  2020-01-26       2118.0      685.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 82045                 NaN          17.0         0.0                  NaN  ...
# 82046                 NaN          18.0         1.0                  NaN  ...
# 82047                 NaN          26.0         8.0                  NaN  ...
# 82048                 NaN          42.0        16.0                  NaN  ...
# 82049                 NaN          56.0        14.0                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 82045       15469.207             10.0                 233.07
# 82046       15469.207             10.0                 233.07
# 82047       15469.207             10.0                 233.07
# 82048       15469.207             10.0                 233.07
# 82049       15469.207             10.0                 233.07
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 82045                 8.51           6.434        34.635
# 82046                 8.51           6.434        34.635
# 82047                 8.51           6.434        34.635
# 82048                 8.51           6.434        34.635
# 82049                 8.51           6.434        34.635
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 82045                   60.13                       2.705            72.58
# 82046                   60.13                       2.705            72.58
# 82047                   60.13                       2.705            72.58
# 82048                   60.13                       2.705            72.58
# 82049                   60.13                       2.705            72.58
#
#        human_development_index
# 82045                    0.737
# 82046                    0.737
# 82047                    0.737
# 82048                    0.737
# 82049                    0.737
#
# [5 rows x 59 columns]

# %%
db = pd.read_csv(url)

# %%
db.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
world = db[db["location"] == "World"]
country = db[db["location"] == "Bangladesh"]

# %%
world.tail(3)
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 82501  OWID_WRL       NaN    World  2021-04-22  144742651.0   899831.0
# 82502  OWID_WRL       NaN    World  2021-04-23  145640413.0   897762.0
# 82503  OWID_WRL       NaN    World  2021-04-24          NaN        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 82501          809435.000     3071857.0     13712.0            12274.857  ...
# 82502          815564.571     3086150.0     14293.0            12484.429  ...
# 82503                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 82501       15469.207             10.0                 233.07
# 82502       15469.207             10.0                 233.07
# 82503       15469.207             10.0                 233.07
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 82501                 8.51           6.434        34.635
# 82502                 8.51           6.434        34.635
# 82503                 8.51           6.434        34.635
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 82501                   60.13                       2.705            72.58
# 82502                   60.13                       2.705            72.58
# 82503                   60.13                       2.705            72.58
#
#        human_development_index
# 82501                    0.737
# 82502                    0.737
# 82503                    0.737
#
# [3 rows x 59 columns]

# %%
world_total = world[["location", "date", "total_cases", "total_deaths"]]
country_total = country[["location", "date", "total_cases", "total_deaths"]]

# %%
world_total = pd.DataFrame(world_total)
world_total.insert(0, 'id', range(0, 0 + len(world_total)))
country_total = pd.DataFrame(country_total)
country_total.insert(0, 'id', range(0, 0 + len(country_total)))

# %%
world_total
last_date = world_total.tail(1)
last_date
last_cases = int(last_date["total_cases"])
last_cases
last_death = int(last_date["total_deaths"])
last_death
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3c83c381a299> in <module>
#       2 last_date = world_total.tail(1)
#       3 last_date
# ----> 4 last_cases = int(last_date["total_cases"])
#       5 last_cases
#       6 last_death = int(last_date["total_deaths"])
#
# c:\users\hridoy\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in wrapper(self)
#     136     def wrapper(self):
#     137         if len(self) == 1:
# --> 138             return converter(self.iloc[0])
#     139         raise TypeError(f"cannot convert the series to {converter}")
#     140
#
# ValueError: cannot convert float NaN to integer

# %%
world_data = world_total[["id", "date", "total_cases"]]
world_total

# %%
x = np.array(world_total["id"]).reshape(-1,1)
y = np.array(world_total["total_cases"]).reshape(-1,1)

# %%
# %matplotlib widget
plt.plot(x, y, color='red', marker='o', label='Total Cases')
plt.xlabel('Days')
plt.ylabel('Increment - Milions')
plt.title("Total Cases Worldwide")
plt.grid(True)
plt.legend()

# %%
world_country = [world_total,country_total]
world_country = pd.concat(world_country)

# %%
fig = px.line(world_country, x="date", y="total_cases", title='Total Cases World and Country', color='location')
fig.show()

# %%
xx = world_total["date"]
yy = world_total["total_cases"]

fig = go.Figure(data=go.Scatter(x=xx, y=yy))
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import mpld3

f, ax = plt.subplots()
xxx = world_total["date"]
yyy = world_total["total_cases"]

line = ax.plot(xxx, yyy)
mpld3.plugins.connect(f, mpld3.plugins.LineLabelTooltip(line[0], label='label 1'))

# mpld3.show()
# mpld3.display()
mpld3.enable_notebook()

# %%
regressor = LinearRegression()
regressor.fit(x, y)
y_pred = regressor.predict([[456]])
str(int(y_pred))

# %%
poly = PolynomialFeatures(degree=3)
x = poly.fit_transform(x)
x

# %%
reg = LinearRegression()
reg.fit(x, y)
accuracy = reg.score(x,y)
print(f"Accuracy = {round(accuracy*100, 2)} %")
predict = reg.predict(x)


# %matplotlib widget
plt.plot(predict, color='red', marker='o', label='Total Cases')
plt.xlabel('Days')
plt.ylabel('Increment - Milions')
plt.title("Total Cases Worldwide")
plt.grid(True)
plt.legend()

# %%
print(int(reg.predict(poly.fit_transform([[457]]))))
